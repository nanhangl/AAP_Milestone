# %% [markdown]
# Lim Nan Hang 190704D

# %% [markdown]
# # Introduction
#
# Object Detection is used to detect doors and stairs to help the blind to navigate easier while travelling

# %% [markdown]
# # Data Collection
#
# Door dataset (images containing only door) was obtained from https://github.com/gasparramoa/DeepDoors2
#
# Stairs dataset (images containing only stairs) was obtained from http://enorasi.dib.uth.gr/database/index.html
#
# Door + Stairs (images containing both door and stairs) dataset images are collated from Unsplash, Flickr, Pexels, and Google

# %% [markdown]
# # Data Preparation
#
# 1. Resized images to fit to pretrained model's input size
#
# 2. Removed images that do not match label (e.g. escalator in stairs dataset)
#
# 3. Rename label for stairs dataset (upstairs and downstairs to stairs)
#
# 4. Labelled images using labelImg
# - Most of the stairs images are prelabelled
# - Drew additional bounding boxes for stairs (image shows multiple stairs, but only one bounding box was prelabelled)
#
# 5. Partition dataset into train and test using code from https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/_downloads/d0e545609c5f7f49f39abc7b6a38cec3/partition_dataset.py
#
# 6. Created tfrecord for train and test using code from https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/_downloads/da4babe668a8afb093cc7776d7e630f3/generate_tfrecord.py

# %%
# code for resizing images

import glob, os
from PIL import Image

os.chdir("img_dir")
fileList = os.listdir()

for fileName in glob.glob("*.jpg"):
    image = Image.open(fileName)
    image.thumbnail((500, 500))
    image.save(fileName)

# %%
# code for renaming labels (for images with only one bounding box)

import glob, os
import xml.etree.ElementTree as ET

os.chdir("annotations_dir")
fileList = os.listdir()

for fileName in glob.glob("*.xml"):
    xmlTree = ET.parse(fileName)
    rootElement = xmlTree.getroot()
    objectElement = rootElement.find("object")
    nameElement = objectElement.find("name")
    nameElement.text = "stairs"
    xmlTree.write(fileName, encoding='UTF-8', xml_declaration=True)

# %% [markdown]
# # Model Training and Experiments
#
# Choosing pretrained model
# - Pretrained model should be small enough to be used in a mobile phone
# - Pretrained model should be fast in detection
# - Pretrained model should have good mAP
#
# Candidate: EfficientDet D0 (20.4 MB for saved_model.pb, speed 39ms, 33.6 mAP)
#
# Edited model's pipeline.config to add additional data augmentation (availble in run3 directory for reference)

# %% [markdown]
# ## trained by running train.sh in terminal, below is the copied output

# %% [raw]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1215 14:05:10.658657 139683018876736 mirrored_strategy.py:376] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 10000
# I1215 14:05:10.666630 139683018876736 config_util.py:552] Maybe overwriting train_steps: 10000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1215 14:05:10.666766 139683018876736 config_util.py:552] Maybe overwriting use_bfloat16: False
# I1215 14:05:11.033493 139683018876736 ssd_efficientnet_bifpn_feature_extractor.py:142] EfficientDet EfficientNet backbone version: efficientnet-b0
# I1215 14:05:11.033624 139683018876736 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 64
# I1215 14:05:11.033685 139683018876736 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet BiFPN num iterations: 3
# I1215 14:05:11.037002 139683018876736 efficientnet_model.py:147] round_filter input=32 output=32
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.076190 139683018876736 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.084275 139683018876736 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.086055 139683018876736 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.086857 139683018876736 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.094391 139683018876736 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.097142 139683018876736 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.101785 139683018876736 efficientnet_model.py:147] round_filter input=32 output=32
# I1215 14:05:11.101867 139683018876736 efficientnet_model.py:147] round_filter input=16 output=16
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.113368 139683018876736 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.114139 139683018876736 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.115529 139683018876736 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.116287 139683018876736 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1215 14:05:11.176200 139683018876736 efficientnet_model.py:147] round_filter input=16 output=16
# I1215 14:05:11.176290 139683018876736 efficientnet_model.py:147] round_filter input=24 output=24
# I1215 14:05:11.366254 139683018876736 efficientnet_model.py:147] round_filter input=24 output=24
# I1215 14:05:11.366344 139683018876736 efficientnet_model.py:147] round_filter input=40 output=40
# I1215 14:05:11.554820 139683018876736 efficientnet_model.py:147] round_filter input=40 output=40
# I1215 14:05:11.554917 139683018876736 efficientnet_model.py:147] round_filter input=80 output=80
# I1215 14:05:11.838612 139683018876736 efficientnet_model.py:147] round_filter input=80 output=80
# I1215 14:05:11.838712 139683018876736 efficientnet_model.py:147] round_filter input=112 output=112
# I1215 14:05:12.148081 139683018876736 efficientnet_model.py:147] round_filter input=112 output=112
# I1215 14:05:12.148215 139683018876736 efficientnet_model.py:147] round_filter input=192 output=192
# I1215 14:05:12.526127 139683018876736 efficientnet_model.py:147] round_filter input=192 output=192
# I1215 14:05:12.526262 139683018876736 efficientnet_model.py:147] round_filter input=320 output=320
# I1215 14:05:12.618444 139683018876736 efficientnet_model.py:147] round_filter input=1280 output=1280
# I1215 14:05:12.657430 139683018876736 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# WARNING:tensorflow:From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1215 14:05:12.691682 139683018876736 deprecation.py:341] From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['annotations/train.record']
# I1215 14:05:12.700994 139683018876736 dataset_builder.py:163] Reading unweighted datasets: ['annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['annotations/train.record']
# I1215 14:05:12.701156 139683018876736 dataset_builder.py:80] Reading record datasets for input file: ['annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1215 14:05:12.701259 139683018876736 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1215 14:05:12.701319 139683018876736 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:101: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1215 14:05:12.708212 139683018876736 deprecation.py:341] From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:101: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1215 14:05:12.735121 139683018876736 deprecation.py:341] From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1096: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1215 14:05:18.360106 139683018876736 deprecation.py:341] From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1096: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:465: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1215 14:05:21.647601 139683018876736 deprecation.py:341] From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:465: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/keras/backend.py:414: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# WARNING:tensorflow:From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:620: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W1215 14:05:49.834172 139662467729152 deprecation.py:545] From /home/studio-lab-user/.conda/envs/studiolab/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:620: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# W1215 14:05:56.930866 139662467729152 utils.py:76] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# W1215 14:06:06.694587 139662467729152 utils.py:76] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# W1215 14:06:15.984172 139662467729152 utils.py:76] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# W1215 14:06:25.681885 139662467729152 utils.py:76] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# INFO:tensorflow:Step 100 per-step time 1.066s
# I1215 14:07:36.115363 139683018876736 model_lib_v2.py:705] Step 100 per-step time 1.066s
# INFO:tensorflow:{'Loss/classification_loss': 1.1079048,
#  'Loss/localization_loss': 0.021997174,
#  'Loss/regularization_loss': 0.028341625,
#  'Loss/total_loss': 1.1582437,
#  'learning_rate': 0.00416}
# I1215 14:07:36.115742 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 1.1079048,
#  'Loss/localization_loss': 0.021997174,
#  'Loss/regularization_loss': 0.028341625,
#  'Loss/total_loss': 1.1582437,
#  'learning_rate': 0.00416}
# INFO:tensorflow:Step 200 per-step time 0.523s
# I1215 14:08:28.423711 139683018876736 model_lib_v2.py:705] Step 200 per-step time 0.523s
# INFO:tensorflow:{'Loss/classification_loss': 0.537728,
#  'Loss/localization_loss': 0.013915211,
#  'Loss/regularization_loss': 0.02836463,
#  'Loss/total_loss': 0.5800079,
#  'learning_rate': 0.0073200003}
# I1215 14:08:28.423961 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.537728,
#  'Loss/localization_loss': 0.013915211,
#  'Loss/regularization_loss': 0.02836463,
#  'Loss/total_loss': 0.5800079,
#  'learning_rate': 0.0073200003}
# INFO:tensorflow:Step 300 per-step time 0.531s
# I1215 14:09:21.475520 139683018876736 model_lib_v2.py:705] Step 300 per-step time 0.531s
# INFO:tensorflow:{'Loss/classification_loss': 0.5036662,
#  'Loss/localization_loss': 0.014085341,
#  'Loss/regularization_loss': 0.028403552,
#  'Loss/total_loss': 0.54615515,
#  'learning_rate': 0.010480001}
# I1215 14:09:21.475764 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.5036662,
#  'Loss/localization_loss': 0.014085341,
#  'Loss/regularization_loss': 0.028403552,
#  'Loss/total_loss': 0.54615515,
#  'learning_rate': 0.010480001}
# INFO:tensorflow:Step 400 per-step time 0.534s
# I1215 14:10:14.901416 139683018876736 model_lib_v2.py:705] Step 400 per-step time 0.534s
# INFO:tensorflow:{'Loss/classification_loss': 0.41829124,
#  'Loss/localization_loss': 0.012224773,
#  'Loss/regularization_loss': 0.028457785,
#  'Loss/total_loss': 0.4589738,
#  'learning_rate': 0.0136400005}
# I1215 14:10:14.901658 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.41829124,
#  'Loss/localization_loss': 0.012224773,
#  'Loss/regularization_loss': 0.028457785,
#  'Loss/total_loss': 0.4589738,
#  'learning_rate': 0.0136400005}
# INFO:tensorflow:Step 500 per-step time 0.539s
# I1215 14:11:08.786161 139683018876736 model_lib_v2.py:705] Step 500 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.53876126,
#  'Loss/localization_loss': 0.017970394,
#  'Loss/regularization_loss': 0.028514575,
#  'Loss/total_loss': 0.5852462,
#  'learning_rate': 0.016800001}
# I1215 14:11:08.786427 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.53876126,
#  'Loss/localization_loss': 0.017970394,
#  'Loss/regularization_loss': 0.028514575,
#  'Loss/total_loss': 0.5852462,
#  'learning_rate': 0.016800001}
# INFO:tensorflow:Step 600 per-step time 0.539s
# I1215 14:12:02.727887 139683018876736 model_lib_v2.py:705] Step 600 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.37942815,
#  'Loss/localization_loss': 0.013962629,
#  'Loss/regularization_loss': 0.028585436,
#  'Loss/total_loss': 0.4219762,
#  'learning_rate': 0.019960001}
# I1215 14:12:02.728175 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.37942815,
#  'Loss/localization_loss': 0.013962629,
#  'Loss/regularization_loss': 0.028585436,
#  'Loss/total_loss': 0.4219762,
#  'learning_rate': 0.019960001}
# INFO:tensorflow:Step 700 per-step time 0.545s
# I1215 14:12:57.195113 139683018876736 model_lib_v2.py:705] Step 700 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.28247207,
#  'Loss/localization_loss': 0.005704799,
#  'Loss/regularization_loss': 0.02867146,
#  'Loss/total_loss': 0.31684834,
#  'learning_rate': 0.023120001}
# I1215 14:12:57.195356 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.28247207,
#  'Loss/localization_loss': 0.005704799,
#  'Loss/regularization_loss': 0.02867146,
#  'Loss/total_loss': 0.31684834,
#  'learning_rate': 0.023120001}
# INFO:tensorflow:Step 800 per-step time 0.546s
# I1215 14:13:51.818231 139683018876736 model_lib_v2.py:705] Step 800 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.3142787,
#  'Loss/localization_loss': 0.009462377,
#  'Loss/regularization_loss': 0.028768511,
#  'Loss/total_loss': 0.3525096,
#  'learning_rate': 0.02628}
# I1215 14:13:51.818481 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.3142787,
#  'Loss/localization_loss': 0.009462377,
#  'Loss/regularization_loss': 0.028768511,
#  'Loss/total_loss': 0.3525096,
#  'learning_rate': 0.02628}
# INFO:tensorflow:Step 900 per-step time 0.541s
# I1215 14:14:45.892080 139683018876736 model_lib_v2.py:705] Step 900 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.51603675,
#  'Loss/localization_loss': 0.014451365,
#  'Loss/regularization_loss': 0.028860945,
#  'Loss/total_loss': 0.55934906,
#  'learning_rate': 0.02944}
# I1215 14:14:45.892371 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.51603675,
#  'Loss/localization_loss': 0.014451365,
#  'Loss/regularization_loss': 0.028860945,
#  'Loss/total_loss': 0.55934906,
#  'learning_rate': 0.02944}
# INFO:tensorflow:Step 1000 per-step time 0.542s
# I1215 14:15:40.075505 139683018876736 model_lib_v2.py:705] Step 1000 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.37739667,
#  'Loss/localization_loss': 0.011284392,
#  'Loss/regularization_loss': 0.028975742,
#  'Loss/total_loss': 0.4176568,
#  'learning_rate': 0.0326}
# I1215 14:15:40.075792 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.37739667,
#  'Loss/localization_loss': 0.011284392,
#  'Loss/regularization_loss': 0.028975742,
#  'Loss/total_loss': 0.4176568,
#  'learning_rate': 0.0326}
# INFO:tensorflow:Step 1100 per-step time 0.553s
# I1215 14:16:35.420446 139683018876736 model_lib_v2.py:705] Step 1100 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.22573061,
#  'Loss/localization_loss': 0.0077094235,
#  'Loss/regularization_loss': 0.029121162,
#  'Loss/total_loss': 0.2625612,
#  'learning_rate': 0.03576}
# I1215 14:16:35.421918 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.22573061,
#  'Loss/localization_loss': 0.0077094235,
#  'Loss/regularization_loss': 0.029121162,
#  'Loss/total_loss': 0.2625612,
#  'learning_rate': 0.03576}
# INFO:tensorflow:Step 1200 per-step time 0.538s
# I1215 14:17:29.198292 139683018876736 model_lib_v2.py:705] Step 1200 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.3113008,
#  'Loss/localization_loss': 0.008546093,
#  'Loss/regularization_loss': 0.029231515,
#  'Loss/total_loss': 0.34907842,
#  'learning_rate': 0.03892}
# I1215 14:17:29.198579 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.3113008,
#  'Loss/localization_loss': 0.008546093,
#  'Loss/regularization_loss': 0.029231515,
#  'Loss/total_loss': 0.34907842,
#  'learning_rate': 0.03892}
# INFO:tensorflow:Step 1300 per-step time 0.545s
# I1215 14:18:23.669113 139683018876736 model_lib_v2.py:705] Step 1300 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.23674065,
#  'Loss/localization_loss': 0.0058421376,
#  'Loss/regularization_loss': 0.029431276,
#  'Loss/total_loss': 0.27201405,
#  'learning_rate': 0.04208}
# I1215 14:18:23.669364 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.23674065,
#  'Loss/localization_loss': 0.0058421376,
#  'Loss/regularization_loss': 0.029431276,
#  'Loss/total_loss': 0.27201405,
#  'learning_rate': 0.04208}
# INFO:tensorflow:Step 1400 per-step time 0.538s
# I1215 14:19:17.437733 139683018876736 model_lib_v2.py:705] Step 1400 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.24862583,
#  'Loss/localization_loss': 0.007732991,
#  'Loss/regularization_loss': 0.02958373,
#  'Loss/total_loss': 0.28594255,
#  'learning_rate': 0.04524}
# I1215 14:19:17.438050 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.24862583,
#  'Loss/localization_loss': 0.007732991,
#  'Loss/regularization_loss': 0.02958373,
#  'Loss/total_loss': 0.28594255,
#  'learning_rate': 0.04524}
# INFO:tensorflow:Step 1500 per-step time 0.536s
# I1215 14:20:10.989210 139683018876736 model_lib_v2.py:705] Step 1500 per-step time 0.536s
# INFO:tensorflow:{'Loss/classification_loss': 0.34578848,
#  'Loss/localization_loss': 0.011015942,
#  'Loss/regularization_loss': 0.029742686,
#  'Loss/total_loss': 0.38654712,
#  'learning_rate': 0.0484}
# I1215 14:20:10.989487 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.34578848,
#  'Loss/localization_loss': 0.011015942,
#  'Loss/regularization_loss': 0.029742686,
#  'Loss/total_loss': 0.38654712,
#  'learning_rate': 0.0484}
# INFO:tensorflow:Step 1600 per-step time 0.545s
# I1215 14:21:05.515541 139683018876736 model_lib_v2.py:705] Step 1600 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.22591431,
#  'Loss/localization_loss': 0.00545529,
#  'Loss/regularization_loss': 0.02991298,
#  'Loss/total_loss': 0.2612826,
#  'learning_rate': 0.05156}
# I1215 14:21:05.515781 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.22591431,
#  'Loss/localization_loss': 0.00545529,
#  'Loss/regularization_loss': 0.02991298,
#  'Loss/total_loss': 0.2612826,
#  'learning_rate': 0.05156}
# INFO:tensorflow:Step 1700 per-step time 0.539s
# I1215 14:21:59.398088 139683018876736 model_lib_v2.py:705] Step 1700 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.4626929,
#  'Loss/localization_loss': 0.009801839,
#  'Loss/regularization_loss': 0.030101884,
#  'Loss/total_loss': 0.5025966,
#  'learning_rate': 0.05472}
# I1215 14:21:59.398352 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.4626929,
#  'Loss/localization_loss': 0.009801839,
#  'Loss/regularization_loss': 0.030101884,
#  'Loss/total_loss': 0.5025966,
#  'learning_rate': 0.05472}
# INFO:tensorflow:Step 1800 per-step time 0.538s
# I1215 14:22:53.186954 139683018876736 model_lib_v2.py:705] Step 1800 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.16882247,
#  'Loss/localization_loss': 0.0055885846,
#  'Loss/regularization_loss': 0.030290863,
#  'Loss/total_loss': 0.20470192,
#  'learning_rate': 0.05788}
# I1215 14:22:53.187200 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.16882247,
#  'Loss/localization_loss': 0.0055885846,
#  'Loss/regularization_loss': 0.030290863,
#  'Loss/total_loss': 0.20470192,
#  'learning_rate': 0.05788}
# INFO:tensorflow:Step 1900 per-step time 0.542s
# I1215 14:23:47.358285 139683018876736 model_lib_v2.py:705] Step 1900 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.37696138,
#  'Loss/localization_loss': 0.007892082,
#  'Loss/regularization_loss': 0.0305628,
#  'Loss/total_loss': 0.41541624,
#  'learning_rate': 0.06104}
# I1215 14:23:47.358565 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.37696138,
#  'Loss/localization_loss': 0.007892082,
#  'Loss/regularization_loss': 0.0305628,
#  'Loss/total_loss': 0.41541624,
#  'learning_rate': 0.06104}
# INFO:tensorflow:Step 2000 per-step time 0.538s
# I1215 14:24:41.177571 139683018876736 model_lib_v2.py:705] Step 2000 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.2882429,
#  'Loss/localization_loss': 0.0060756076,
#  'Loss/regularization_loss': 0.030816102,
#  'Loss/total_loss': 0.32513463,
#  'learning_rate': 0.06420001}
# I1215 14:24:41.177844 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.2882429,
#  'Loss/localization_loss': 0.0060756076,
#  'Loss/regularization_loss': 0.030816102,
#  'Loss/total_loss': 0.32513463,
#  'learning_rate': 0.06420001}
# INFO:tensorflow:Step 2100 per-step time 0.545s
# I1215 14:25:35.671208 139683018876736 model_lib_v2.py:705] Step 2100 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.3367996,
#  'Loss/localization_loss': 0.0076518287,
#  'Loss/regularization_loss': 0.031008191,
#  'Loss/total_loss': 0.3754596,
#  'learning_rate': 0.067360006}
# I1215 14:25:35.671461 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.3367996,
#  'Loss/localization_loss': 0.0076518287,
#  'Loss/regularization_loss': 0.031008191,
#  'Loss/total_loss': 0.3754596,
#  'learning_rate': 0.067360006}
# INFO:tensorflow:Step 2200 per-step time 0.542s
# I1215 14:26:29.830060 139683018876736 model_lib_v2.py:705] Step 2200 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.20337115,
#  'Loss/localization_loss': 0.0062235394,
#  'Loss/regularization_loss': 0.031259198,
#  'Loss/total_loss': 0.24085389,
#  'learning_rate': 0.070520006}
# I1215 14:26:29.830326 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.20337115,
#  'Loss/localization_loss': 0.0062235394,
#  'Loss/regularization_loss': 0.031259198,
#  'Loss/total_loss': 0.24085389,
#  'learning_rate': 0.070520006}
# INFO:tensorflow:Step 2300 per-step time 0.542s
# I1215 14:27:23.982957 139683018876736 model_lib_v2.py:705] Step 2300 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.2842324,
#  'Loss/localization_loss': 0.009181102,
#  'Loss/regularization_loss': 0.03154225,
#  'Loss/total_loss': 0.32495576,
#  'learning_rate': 0.073680006}
# I1215 14:27:23.983246 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.2842324,
#  'Loss/localization_loss': 0.009181102,
#  'Loss/regularization_loss': 0.03154225,
#  'Loss/total_loss': 0.32495576,
#  'learning_rate': 0.073680006}
# INFO:tensorflow:Step 2400 per-step time 0.545s
# I1215 14:28:18.525703 139683018876736 model_lib_v2.py:705] Step 2400 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.35525703,
#  'Loss/localization_loss': 0.019176757,
#  'Loss/regularization_loss': 0.03178188,
#  'Loss/total_loss': 0.40621567,
#  'learning_rate': 0.076840006}
# I1215 14:28:18.525961 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.35525703,
#  'Loss/localization_loss': 0.019176757,
#  'Loss/regularization_loss': 0.03178188,
#  'Loss/total_loss': 0.40621567,
#  'learning_rate': 0.076840006}
# INFO:tensorflow:Step 2500 per-step time 0.538s
# I1215 14:29:12.370442 139683018876736 model_lib_v2.py:705] Step 2500 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.31376222,
#  'Loss/localization_loss': 0.008521952,
#  'Loss/regularization_loss': 0.032164957,
#  'Loss/total_loss': 0.35444912,
#  'learning_rate': 0.08}
# I1215 14:29:12.371969 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.31376222,
#  'Loss/localization_loss': 0.008521952,
#  'Loss/regularization_loss': 0.032164957,
#  'Loss/total_loss': 0.35444912,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 2600 per-step time 0.541s
# I1215 14:30:06.507012 139683018876736 model_lib_v2.py:705] Step 2600 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.20295179,
#  'Loss/localization_loss': 0.00470905,
#  'Loss/regularization_loss': 0.032383867,
#  'Loss/total_loss': 0.24004471,
#  'learning_rate': 0.079999976}
# I1215 14:30:06.507291 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.20295179,
#  'Loss/localization_loss': 0.00470905,
#  'Loss/regularization_loss': 0.032383867,
#  'Loss/total_loss': 0.24004471,
#  'learning_rate': 0.079999976}
# INFO:tensorflow:Step 2700 per-step time 0.540s
# I1215 14:31:00.545077 139683018876736 model_lib_v2.py:705] Step 2700 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.20104088,
#  'Loss/localization_loss': 0.002998165,
#  'Loss/regularization_loss': 0.032622624,
#  'Loss/total_loss': 0.23666166,
#  'learning_rate': 0.07999991}
# I1215 14:31:00.545327 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.20104088,
#  'Loss/localization_loss': 0.002998165,
#  'Loss/regularization_loss': 0.032622624,
#  'Loss/total_loss': 0.23666166,
#  'learning_rate': 0.07999991}
# INFO:tensorflow:Step 2800 per-step time 0.540s
# I1215 14:31:54.567180 139683018876736 model_lib_v2.py:705] Step 2800 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.32823098,
#  'Loss/localization_loss': 0.009041293,
#  'Loss/regularization_loss': 0.032825567,
#  'Loss/total_loss': 0.37009782,
#  'learning_rate': 0.0799998}
# I1215 14:31:54.567418 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.32823098,
#  'Loss/localization_loss': 0.009041293,
#  'Loss/regularization_loss': 0.032825567,
#  'Loss/total_loss': 0.37009782,
#  'learning_rate': 0.0799998}
# INFO:tensorflow:Step 2900 per-step time 0.510s
# I1215 14:32:45.553149 139683018876736 model_lib_v2.py:705] Step 2900 per-step time 0.510s
# INFO:tensorflow:{'Loss/classification_loss': 0.15931834,
#  'Loss/localization_loss': 0.004248464,
#  'Loss/regularization_loss': 0.032999866,
#  'Loss/total_loss': 0.19656667,
#  'learning_rate': 0.07999964}
# I1215 14:32:45.553414 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.15931834,
#  'Loss/localization_loss': 0.004248464,
#  'Loss/regularization_loss': 0.032999866,
#  'Loss/total_loss': 0.19656667,
#  'learning_rate': 0.07999964}
# INFO:tensorflow:Step 3000 per-step time 0.510s
# I1215 14:33:36.553659 139683018876736 model_lib_v2.py:705] Step 3000 per-step time 0.510s
# INFO:tensorflow:{'Loss/classification_loss': 0.2504204,
#  'Loss/localization_loss': 0.0043594944,
#  'Loss/regularization_loss': 0.033158943,
#  'Loss/total_loss': 0.28793883,
#  'learning_rate': 0.07999944}
# I1215 14:33:36.553937 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.2504204,
#  'Loss/localization_loss': 0.0043594944,
#  'Loss/regularization_loss': 0.033158943,
#  'Loss/total_loss': 0.28793883,
#  'learning_rate': 0.07999944}
# INFO:tensorflow:Step 3100 per-step time 0.513s
# I1215 14:34:27.807891 139683018876736 model_lib_v2.py:705] Step 3100 per-step time 0.513s
# INFO:tensorflow:{'Loss/classification_loss': 0.22976457,
#  'Loss/localization_loss': 0.0055924235,
#  'Loss/regularization_loss': 0.033299036,
#  'Loss/total_loss': 0.26865602,
#  'learning_rate': 0.07999919}
# I1215 14:34:27.808154 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.22976457,
#  'Loss/localization_loss': 0.0055924235,
#  'Loss/regularization_loss': 0.033299036,
#  'Loss/total_loss': 0.26865602,
#  'learning_rate': 0.07999919}
# INFO:tensorflow:Step 3200 per-step time 0.507s
# I1215 14:35:18.523743 139683018876736 model_lib_v2.py:705] Step 3200 per-step time 0.507s
# INFO:tensorflow:{'Loss/classification_loss': 0.27092838,
#  'Loss/localization_loss': 0.00561708,
#  'Loss/regularization_loss': 0.03346439,
#  'Loss/total_loss': 0.31000987,
#  'learning_rate': 0.0799989}
# I1215 14:35:18.523987 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.27092838,
#  'Loss/localization_loss': 0.00561708,
#  'Loss/regularization_loss': 0.03346439,
#  'Loss/total_loss': 0.31000987,
#  'learning_rate': 0.0799989}
# INFO:tensorflow:Step 3300 per-step time 0.509s
# I1215 14:36:09.419240 139683018876736 model_lib_v2.py:705] Step 3300 per-step time 0.509s
# INFO:tensorflow:{'Loss/classification_loss': 0.22099978,
#  'Loss/localization_loss': 0.005958931,
#  'Loss/regularization_loss': 0.03357406,
#  'Loss/total_loss': 0.26053277,
#  'learning_rate': 0.07999857}
# I1215 14:36:09.419491 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.22099978,
#  'Loss/localization_loss': 0.005958931,
#  'Loss/regularization_loss': 0.03357406,
#  'Loss/total_loss': 0.26053277,
#  'learning_rate': 0.07999857}
# INFO:tensorflow:Step 3400 per-step time 0.506s
# I1215 14:37:00.067579 139683018876736 model_lib_v2.py:705] Step 3400 per-step time 0.506s
# INFO:tensorflow:{'Loss/classification_loss': 0.24062254,
#  'Loss/localization_loss': 0.008645507,
#  'Loss/regularization_loss': 0.03374746,
#  'Loss/total_loss': 0.2830155,
#  'learning_rate': 0.07999819}
# I1215 14:37:00.067859 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.24062254,
#  'Loss/localization_loss': 0.008645507,
#  'Loss/regularization_loss': 0.03374746,
#  'Loss/total_loss': 0.2830155,
#  'learning_rate': 0.07999819}
# INFO:tensorflow:Step 3500 per-step time 0.506s
# I1215 14:37:50.715060 139683018876736 model_lib_v2.py:705] Step 3500 per-step time 0.506s
# INFO:tensorflow:{'Loss/classification_loss': 0.22065274,
#  'Loss/localization_loss': 0.007583009,
#  'Loss/regularization_loss': 0.03387707,
#  'Loss/total_loss': 0.26211283,
#  'learning_rate': 0.07999776}
# I1215 14:37:50.715344 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.22065274,
#  'Loss/localization_loss': 0.007583009,
#  'Loss/regularization_loss': 0.03387707,
#  'Loss/total_loss': 0.26211283,
#  'learning_rate': 0.07999776}
# INFO:tensorflow:Step 3600 per-step time 0.513s
# I1215 14:38:42.012374 139683018876736 model_lib_v2.py:705] Step 3600 per-step time 0.513s
# INFO:tensorflow:{'Loss/classification_loss': 0.16306858,
#  'Loss/localization_loss': 0.0025813265,
#  'Loss/regularization_loss': 0.034026377,
#  'Loss/total_loss': 0.19967628,
#  'learning_rate': 0.0799973}
# I1215 14:38:42.012623 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.16306858,
#  'Loss/localization_loss': 0.0025813265,
#  'Loss/regularization_loss': 0.034026377,
#  'Loss/total_loss': 0.19967628,
#  'learning_rate': 0.0799973}
# INFO:tensorflow:Step 3700 per-step time 0.507s
# I1215 14:39:32.682571 139683018876736 model_lib_v2.py:705] Step 3700 per-step time 0.507s
# INFO:tensorflow:{'Loss/classification_loss': 0.1858109,
#  'Loss/localization_loss': 0.0053717224,
#  'Loss/regularization_loss': 0.034150086,
#  'Loss/total_loss': 0.2253327,
#  'learning_rate': 0.07999679}
# I1215 14:39:32.682824 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.1858109,
#  'Loss/localization_loss': 0.0053717224,
#  'Loss/regularization_loss': 0.034150086,
#  'Loss/total_loss': 0.2253327,
#  'learning_rate': 0.07999679}
# INFO:tensorflow:Step 3800 per-step time 0.515s
# I1215 14:40:24.186352 139683018876736 model_lib_v2.py:705] Step 3800 per-step time 0.515s
# INFO:tensorflow:{'Loss/classification_loss': 0.30885753,
#  'Loss/localization_loss': 0.0071033514,
#  'Loss/regularization_loss': 0.034272864,
#  'Loss/total_loss': 0.35023373,
#  'learning_rate': 0.07999623}
# I1215 14:40:24.186638 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.30885753,
#  'Loss/localization_loss': 0.0071033514,
#  'Loss/regularization_loss': 0.034272864,
#  'Loss/total_loss': 0.35023373,
#  'learning_rate': 0.07999623}
# INFO:tensorflow:Step 3900 per-step time 0.512s
# I1215 14:41:15.418105 139683018876736 model_lib_v2.py:705] Step 3900 per-step time 0.512s
# INFO:tensorflow:{'Loss/classification_loss': 0.20961484,
#  'Loss/localization_loss': 0.004711939,
#  'Loss/regularization_loss': 0.034423668,
#  'Loss/total_loss': 0.24875045,
#  'learning_rate': 0.07999563}
# I1215 14:41:15.418375 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.20961484,
#  'Loss/localization_loss': 0.004711939,
#  'Loss/regularization_loss': 0.034423668,
#  'Loss/total_loss': 0.24875045,
#  'learning_rate': 0.07999563}
# INFO:tensorflow:Step 4000 per-step time 0.520s
# I1215 14:42:07.451608 139683018876736 model_lib_v2.py:705] Step 4000 per-step time 0.520s
# INFO:tensorflow:{'Loss/classification_loss': 0.19203629,
#  'Loss/localization_loss': 0.0045708707,
#  'Loss/regularization_loss': 0.034550615,
#  'Loss/total_loss': 0.23115778,
#  'learning_rate': 0.079994984}
# I1215 14:42:07.451865 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.19203629,
#  'Loss/localization_loss': 0.0045708707,
#  'Loss/regularization_loss': 0.034550615,
#  'Loss/total_loss': 0.23115778,
#  'learning_rate': 0.079994984}
# INFO:tensorflow:Step 4100 per-step time 0.516s
# I1215 14:42:59.044490 139683018876736 model_lib_v2.py:705] Step 4100 per-step time 0.516s
# INFO:tensorflow:{'Loss/classification_loss': 0.25420794,
#  'Loss/localization_loss': 0.0056614825,
#  'Loss/regularization_loss': 0.034628432,
#  'Loss/total_loss': 0.29449785,
#  'learning_rate': 0.07999428}
# I1215 14:42:59.044752 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.25420794,
#  'Loss/localization_loss': 0.0056614825,
#  'Loss/regularization_loss': 0.034628432,
#  'Loss/total_loss': 0.29449785,
#  'learning_rate': 0.07999428}
# INFO:tensorflow:Step 4200 per-step time 0.512s
# I1215 14:43:50.200550 139683018876736 model_lib_v2.py:705] Step 4200 per-step time 0.512s
# INFO:tensorflow:{'Loss/classification_loss': 0.23943622,
#  'Loss/localization_loss': 0.0043505016,
#  'Loss/regularization_loss': 0.03476817,
#  'Loss/total_loss': 0.2785549,
#  'learning_rate': 0.07999355}
# I1215 14:43:50.200835 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.23943622,
#  'Loss/localization_loss': 0.0043505016,
#  'Loss/regularization_loss': 0.03476817,
#  'Loss/total_loss': 0.2785549,
#  'learning_rate': 0.07999355}
# INFO:tensorflow:Step 4300 per-step time 0.514s
# I1215 14:44:41.606638 139683018876736 model_lib_v2.py:705] Step 4300 per-step time 0.514s
# INFO:tensorflow:{'Loss/classification_loss': 0.24180795,
#  'Loss/localization_loss': 0.0049091573,
#  'Loss/regularization_loss': 0.034878965,
#  'Loss/total_loss': 0.28159606,
#  'learning_rate': 0.07999277}
# I1215 14:44:41.606885 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.24180795,
#  'Loss/localization_loss': 0.0049091573,
#  'Loss/regularization_loss': 0.034878965,
#  'Loss/total_loss': 0.28159606,
#  'learning_rate': 0.07999277}
# INFO:tensorflow:Step 4400 per-step time 0.514s
# I1215 14:45:33.010184 139683018876736 model_lib_v2.py:705] Step 4400 per-step time 0.514s
# INFO:tensorflow:{'Loss/classification_loss': 0.25139555,
#  'Loss/localization_loss': 0.0060499967,
#  'Loss/regularization_loss': 0.03501043,
#  'Loss/total_loss': 0.29245597,
#  'learning_rate': 0.07999195}
# I1215 14:45:33.010478 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.25139555,
#  'Loss/localization_loss': 0.0060499967,
#  'Loss/regularization_loss': 0.03501043,
#  'Loss/total_loss': 0.29245597,
#  'learning_rate': 0.07999195}
# INFO:tensorflow:Step 4500 per-step time 0.516s
# I1215 14:46:24.577057 139683018876736 model_lib_v2.py:705] Step 4500 per-step time 0.516s
# INFO:tensorflow:{'Loss/classification_loss': 0.32716474,
#  'Loss/localization_loss': 0.00641184,
#  'Loss/regularization_loss': 0.035107963,
#  'Loss/total_loss': 0.36868456,
#  'learning_rate': 0.07999108}
# I1215 14:46:24.577331 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.32716474,
#  'Loss/localization_loss': 0.00641184,
#  'Loss/regularization_loss': 0.035107963,
#  'Loss/total_loss': 0.36868456,
#  'learning_rate': 0.07999108}
# INFO:tensorflow:Step 4600 per-step time 0.527s
# I1215 14:47:17.257513 139683018876736 model_lib_v2.py:705] Step 4600 per-step time 0.527s
# INFO:tensorflow:{'Loss/classification_loss': 0.19959906,
#  'Loss/localization_loss': 0.0038383345,
#  'Loss/regularization_loss': 0.03518967,
#  'Loss/total_loss': 0.23862706,
#  'learning_rate': 0.07999016}
# I1215 14:47:17.257792 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.19959906,
#  'Loss/localization_loss': 0.0038383345,
#  'Loss/regularization_loss': 0.03518967,
#  'Loss/total_loss': 0.23862706,
#  'learning_rate': 0.07999016}
# INFO:tensorflow:Step 4700 per-step time 0.536s
# I1215 14:48:10.901089 139683018876736 model_lib_v2.py:705] Step 4700 per-step time 0.536s
# INFO:tensorflow:{'Loss/classification_loss': 0.21491688,
#  'Loss/localization_loss': 0.0050596097,
#  'Loss/regularization_loss': 0.035274442,
#  'Loss/total_loss': 0.25525093,
#  'learning_rate': 0.0799892}
# I1215 14:48:10.901360 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.21491688,
#  'Loss/localization_loss': 0.0050596097,
#  'Loss/regularization_loss': 0.035274442,
#  'Loss/total_loss': 0.25525093,
#  'learning_rate': 0.0799892}
# INFO:tensorflow:Step 4800 per-step time 0.538s
# I1215 14:49:04.677126 139683018876736 model_lib_v2.py:705] Step 4800 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.22014806,
#  'Loss/localization_loss': 0.006679767,
#  'Loss/regularization_loss': 0.035383638,
#  'Loss/total_loss': 0.26221147,
#  'learning_rate': 0.079988204}
# I1215 14:49:04.677409 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.22014806,
#  'Loss/localization_loss': 0.006679767,
#  'Loss/regularization_loss': 0.035383638,
#  'Loss/total_loss': 0.26221147,
#  'learning_rate': 0.079988204}
# INFO:tensorflow:Step 4900 per-step time 0.543s
# I1215 14:49:58.974140 139683018876736 model_lib_v2.py:705] Step 4900 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.20639303,
#  'Loss/localization_loss': 0.0039618546,
#  'Loss/regularization_loss': 0.035480592,
#  'Loss/total_loss': 0.24583548,
#  'learning_rate': 0.07998715}
# I1215 14:49:58.974446 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.20639303,
#  'Loss/localization_loss': 0.0039618546,
#  'Loss/regularization_loss': 0.035480592,
#  'Loss/total_loss': 0.24583548,
#  'learning_rate': 0.07998715}
# INFO:tensorflow:Step 5000 per-step time 0.543s
# I1215 14:50:53.287914 139683018876736 model_lib_v2.py:705] Step 5000 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.12084605,
#  'Loss/localization_loss': 0.0017091383,
#  'Loss/regularization_loss': 0.035571307,
#  'Loss/total_loss': 0.1581265,
#  'learning_rate': 0.07998606}
# I1215 14:50:53.288200 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.12084605,
#  'Loss/localization_loss': 0.0017091383,
#  'Loss/regularization_loss': 0.035571307,
#  'Loss/total_loss': 0.1581265,
#  'learning_rate': 0.07998606}
# INFO:tensorflow:Step 5100 per-step time 0.548s
# I1215 14:51:48.080624 139683018876736 model_lib_v2.py:705] Step 5100 per-step time 0.548s
# INFO:tensorflow:{'Loss/classification_loss': 0.28815076,
#  'Loss/localization_loss': 0.005611349,
#  'Loss/regularization_loss': 0.035667643,
#  'Loss/total_loss': 0.32942975,
#  'learning_rate': 0.07998492}
# I1215 14:51:48.080913 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.28815076,
#  'Loss/localization_loss': 0.005611349,
#  'Loss/regularization_loss': 0.035667643,
#  'Loss/total_loss': 0.32942975,
#  'learning_rate': 0.07998492}
# INFO:tensorflow:Step 5200 per-step time 0.513s
# I1215 14:52:39.348949 139683018876736 model_lib_v2.py:705] Step 5200 per-step time 0.513s
# INFO:tensorflow:{'Loss/classification_loss': 0.19469611,
#  'Loss/localization_loss': 0.0037576081,
#  'Loss/regularization_loss': 0.035786945,
#  'Loss/total_loss': 0.23424067,
#  'learning_rate': 0.07998374}
# I1215 14:52:39.349191 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.19469611,
#  'Loss/localization_loss': 0.0037576081,
#  'Loss/regularization_loss': 0.035786945,
#  'Loss/total_loss': 0.23424067,
#  'learning_rate': 0.07998374}
# INFO:tensorflow:Step 5300 per-step time 0.510s
# I1215 14:53:30.398079 139683018876736 model_lib_v2.py:705] Step 5300 per-step time 0.510s
# INFO:tensorflow:{'Loss/classification_loss': 0.24113286,
#  'Loss/localization_loss': 0.0046649836,
#  'Loss/regularization_loss': 0.03589163,
#  'Loss/total_loss': 0.28168947,
#  'learning_rate': 0.07998252}
# I1215 14:53:30.398337 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.24113286,
#  'Loss/localization_loss': 0.0046649836,
#  'Loss/regularization_loss': 0.03589163,
#  'Loss/total_loss': 0.28168947,
#  'learning_rate': 0.07998252}
# INFO:tensorflow:Step 5400 per-step time 0.509s
# I1215 14:54:21.337457 139683018876736 model_lib_v2.py:705] Step 5400 per-step time 0.509s
# INFO:tensorflow:{'Loss/classification_loss': 0.18070628,
#  'Loss/localization_loss': 0.0038531716,
#  'Loss/regularization_loss': 0.035985652,
#  'Loss/total_loss': 0.2205451,
#  'learning_rate': 0.079981245}
# I1215 14:54:21.337699 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.18070628,
#  'Loss/localization_loss': 0.0038531716,
#  'Loss/regularization_loss': 0.035985652,
#  'Loss/total_loss': 0.2205451,
#  'learning_rate': 0.079981245}
# INFO:tensorflow:Step 5500 per-step time 0.511s
# I1215 14:55:12.441122 139683018876736 model_lib_v2.py:705] Step 5500 per-step time 0.511s
# INFO:tensorflow:{'Loss/classification_loss': 0.16787592,
#  'Loss/localization_loss': 0.002950082,
#  'Loss/regularization_loss': 0.036059745,
#  'Loss/total_loss': 0.20688576,
#  'learning_rate': 0.07997993}
# I1215 14:55:12.441361 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.16787592,
#  'Loss/localization_loss': 0.002950082,
#  'Loss/regularization_loss': 0.036059745,
#  'Loss/total_loss': 0.20688576,
#  'learning_rate': 0.07997993}
# INFO:tensorflow:Step 5600 per-step time 0.516s
# I1215 14:56:04.073120 139683018876736 model_lib_v2.py:705] Step 5600 per-step time 0.516s
# INFO:tensorflow:{'Loss/classification_loss': 0.23460291,
#  'Loss/localization_loss': 0.004813281,
#  'Loss/regularization_loss': 0.03612911,
#  'Loss/total_loss': 0.2755453,
#  'learning_rate': 0.07997857}
# I1215 14:56:04.073372 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.23460291,
#  'Loss/localization_loss': 0.004813281,
#  'Loss/regularization_loss': 0.03612911,
#  'Loss/total_loss': 0.2755453,
#  'learning_rate': 0.07997857}
# INFO:tensorflow:Step 5700 per-step time 0.529s
# I1215 14:56:56.960249 139683018876736 model_lib_v2.py:705] Step 5700 per-step time 0.529s
# INFO:tensorflow:{'Loss/classification_loss': 0.27384853,
#  'Loss/localization_loss': 0.0072536073,
#  'Loss/regularization_loss': 0.036158755,
#  'Loss/total_loss': 0.31726092,
#  'learning_rate': 0.07997716}
# I1215 14:56:56.960495 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.27384853,
#  'Loss/localization_loss': 0.0072536073,
#  'Loss/regularization_loss': 0.036158755,
#  'Loss/total_loss': 0.31726092,
#  'learning_rate': 0.07997716}
# INFO:tensorflow:Step 5800 per-step time 0.537s
# I1215 14:57:50.698014 139683018876736 model_lib_v2.py:705] Step 5800 per-step time 0.537s
# INFO:tensorflow:{'Loss/classification_loss': 0.29868725,
#  'Loss/localization_loss': 0.006183795,
#  'Loss/regularization_loss': 0.036227748,
#  'Loss/total_loss': 0.3410988,
#  'learning_rate': 0.07997571}
# I1215 14:57:50.698320 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.29868725,
#  'Loss/localization_loss': 0.006183795,
#  'Loss/regularization_loss': 0.036227748,
#  'Loss/total_loss': 0.3410988,
#  'learning_rate': 0.07997571}
# INFO:tensorflow:Step 5900 per-step time 0.542s
# I1215 14:58:44.888702 139683018876736 model_lib_v2.py:705] Step 5900 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.21014059,
#  'Loss/localization_loss': 0.0031269777,
#  'Loss/regularization_loss': 0.03629845,
#  'Loss/total_loss': 0.24956602,
#  'learning_rate': 0.07997422}
# I1215 14:58:44.888945 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.21014059,
#  'Loss/localization_loss': 0.0031269777,
#  'Loss/regularization_loss': 0.03629845,
#  'Loss/total_loss': 0.24956602,
#  'learning_rate': 0.07997422}
# INFO:tensorflow:Step 6000 per-step time 0.546s
# I1215 14:59:39.489193 139683018876736 model_lib_v2.py:705] Step 6000 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.21868727,
#  'Loss/localization_loss': 0.005522792,
#  'Loss/regularization_loss': 0.036358632,
#  'Loss/total_loss': 0.26056868,
#  'learning_rate': 0.07997268}
# I1215 14:59:39.489439 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.21868727,
#  'Loss/localization_loss': 0.005522792,
#  'Loss/regularization_loss': 0.036358632,
#  'Loss/total_loss': 0.26056868,
#  'learning_rate': 0.07997268}
# INFO:tensorflow:Step 6100 per-step time 0.551s
# I1215 15:00:34.618343 139683018876736 model_lib_v2.py:705] Step 6100 per-step time 0.551s
# INFO:tensorflow:{'Loss/classification_loss': 0.24344456,
#  'Loss/localization_loss': 0.0069207647,
#  'Loss/regularization_loss': 0.03647031,
#  'Loss/total_loss': 0.2868356,
#  'learning_rate': 0.0799711}
# I1215 15:00:34.618623 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.24344456,
#  'Loss/localization_loss': 0.0069207647,
#  'Loss/regularization_loss': 0.03647031,
#  'Loss/total_loss': 0.2868356,
#  'learning_rate': 0.0799711}
# INFO:tensorflow:Step 6200 per-step time 0.540s
# I1215 15:01:28.588807 139683018876736 model_lib_v2.py:705] Step 6200 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.27777636,
#  'Loss/localization_loss': 0.008761504,
#  'Loss/regularization_loss': 0.036555097,
#  'Loss/total_loss': 0.32309294,
#  'learning_rate': 0.07996947}
# I1215 15:01:28.589087 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.27777636,
#  'Loss/localization_loss': 0.008761504,
#  'Loss/regularization_loss': 0.036555097,
#  'Loss/total_loss': 0.32309294,
#  'learning_rate': 0.07996947}
# INFO:tensorflow:Step 6300 per-step time 0.548s
# I1215 15:02:23.369233 139683018876736 model_lib_v2.py:705] Step 6300 per-step time 0.548s
# INFO:tensorflow:{'Loss/classification_loss': 0.19578665,
#  'Loss/localization_loss': 0.003217548,
#  'Loss/regularization_loss': 0.03659931,
#  'Loss/total_loss': 0.23560351,
#  'learning_rate': 0.0799678}
# I1215 15:02:23.369493 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.19578665,
#  'Loss/localization_loss': 0.003217548,
#  'Loss/regularization_loss': 0.03659931,
#  'Loss/total_loss': 0.23560351,
#  'learning_rate': 0.0799678}
# INFO:tensorflow:Step 6400 per-step time 0.541s
# I1215 15:03:17.471537 139683018876736 model_lib_v2.py:705] Step 6400 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.2590737,
#  'Loss/localization_loss': 0.0045827334,
#  'Loss/regularization_loss': 0.036687452,
#  'Loss/total_loss': 0.3003439,
#  'learning_rate': 0.07996608}
# I1215 15:03:17.471850 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.2590737,
#  'Loss/localization_loss': 0.0045827334,
#  'Loss/regularization_loss': 0.036687452,
#  'Loss/total_loss': 0.3003439,
#  'learning_rate': 0.07996608}
# INFO:tensorflow:Step 6500 per-step time 0.540s
# I1215 15:04:11.422180 139683018876736 model_lib_v2.py:705] Step 6500 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.15228407,
#  'Loss/localization_loss': 0.0037170164,
#  'Loss/regularization_loss': 0.036723316,
#  'Loss/total_loss': 0.1927244,
#  'learning_rate': 0.079964325}
# I1215 15:04:11.422442 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.15228407,
#  'Loss/localization_loss': 0.0037170164,
#  'Loss/regularization_loss': 0.036723316,
#  'Loss/total_loss': 0.1927244,
#  'learning_rate': 0.079964325}
# INFO:tensorflow:Step 6600 per-step time 0.543s
# I1215 15:05:05.678922 139683018876736 model_lib_v2.py:705] Step 6600 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.13665816,
#  'Loss/localization_loss': 0.002810775,
#  'Loss/regularization_loss': 0.036807615,
#  'Loss/total_loss': 0.17627655,
#  'learning_rate': 0.079962514}
# I1215 15:05:05.679176 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.13665816,
#  'Loss/localization_loss': 0.002810775,
#  'Loss/regularization_loss': 0.036807615,
#  'Loss/total_loss': 0.17627655,
#  'learning_rate': 0.079962514}
# INFO:tensorflow:Step 6700 per-step time 0.544s
# I1215 15:06:00.034497 139683018876736 model_lib_v2.py:705] Step 6700 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.21380606,
#  'Loss/localization_loss': 0.0042210957,
#  'Loss/regularization_loss': 0.036867473,
#  'Loss/total_loss': 0.25489464,
#  'learning_rate': 0.07996067}
# I1215 15:06:00.034781 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.21380606,
#  'Loss/localization_loss': 0.0042210957,
#  'Loss/regularization_loss': 0.036867473,
#  'Loss/total_loss': 0.25489464,
#  'learning_rate': 0.07996067}
# INFO:tensorflow:Step 6800 per-step time 0.540s
# I1215 15:06:54.046602 139683018876736 model_lib_v2.py:705] Step 6800 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.14781359,
#  'Loss/localization_loss': 0.0028052556,
#  'Loss/regularization_loss': 0.03693398,
#  'Loss/total_loss': 0.18755284,
#  'learning_rate': 0.079958774}
# I1215 15:06:54.046853 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.14781359,
#  'Loss/localization_loss': 0.0028052556,
#  'Loss/regularization_loss': 0.03693398,
#  'Loss/total_loss': 0.18755284,
#  'learning_rate': 0.079958774}
# INFO:tensorflow:Step 6900 per-step time 0.545s
# I1215 15:07:48.505666 139683018876736 model_lib_v2.py:705] Step 6900 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.22899376,
#  'Loss/localization_loss': 0.0051058033,
#  'Loss/regularization_loss': 0.03700495,
#  'Loss/total_loss': 0.2711045,
#  'learning_rate': 0.07995682}
# I1215 15:07:48.505919 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.22899376,
#  'Loss/localization_loss': 0.0051058033,
#  'Loss/regularization_loss': 0.03700495,
#  'Loss/total_loss': 0.2711045,
#  'learning_rate': 0.07995682}
# INFO:tensorflow:Step 7000 per-step time 0.543s
# I1215 15:08:42.833688 139683018876736 model_lib_v2.py:705] Step 7000 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.19942617,
#  'Loss/localization_loss': 0.006595732,
#  'Loss/regularization_loss': 0.037054185,
#  'Loss/total_loss': 0.24307609,
#  'learning_rate': 0.07995484}
# I1215 15:08:42.833935 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.19942617,
#  'Loss/localization_loss': 0.006595732,
#  'Loss/regularization_loss': 0.037054185,
#  'Loss/total_loss': 0.24307609,
#  'learning_rate': 0.07995484}
# INFO:tensorflow:Step 7100 per-step time 0.546s
# I1215 15:09:37.388228 139683018876736 model_lib_v2.py:705] Step 7100 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.08198198,
#  'Loss/localization_loss': 0.0015247525,
#  'Loss/regularization_loss': 0.037088633,
#  'Loss/total_loss': 0.120595366,
#  'learning_rate': 0.07995281}
# I1215 15:09:37.388489 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.08198198,
#  'Loss/localization_loss': 0.0015247525,
#  'Loss/regularization_loss': 0.037088633,
#  'Loss/total_loss': 0.120595366,
#  'learning_rate': 0.07995281}
# INFO:tensorflow:Step 7200 per-step time 0.543s
# I1215 15:10:31.730727 139683018876736 model_lib_v2.py:705] Step 7200 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.17585424,
#  'Loss/localization_loss': 0.0038334061,
#  'Loss/regularization_loss': 0.037188575,
#  'Loss/total_loss': 0.21687622,
#  'learning_rate': 0.07995074}
# I1215 15:10:31.730979 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.17585424,
#  'Loss/localization_loss': 0.0038334061,
#  'Loss/regularization_loss': 0.037188575,
#  'Loss/total_loss': 0.21687622,
#  'learning_rate': 0.07995074}
# INFO:tensorflow:Step 7300 per-step time 0.544s
# I1215 15:11:26.145310 139683018876736 model_lib_v2.py:705] Step 7300 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.37211978,
#  'Loss/localization_loss': 0.007195462,
#  'Loss/regularization_loss': 0.03727021,
#  'Loss/total_loss': 0.41658548,
#  'learning_rate': 0.07994863}
# I1215 15:11:26.145564 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.37211978,
#  'Loss/localization_loss': 0.007195462,
#  'Loss/regularization_loss': 0.03727021,
#  'Loss/total_loss': 0.41658548,
#  'learning_rate': 0.07994863}
# INFO:tensorflow:Step 7400 per-step time 0.542s
# I1215 15:12:20.332889 139683018876736 model_lib_v2.py:705] Step 7400 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.09599545,
#  'Loss/localization_loss': 0.0014659705,
#  'Loss/regularization_loss': 0.037332993,
#  'Loss/total_loss': 0.13479441,
#  'learning_rate': 0.07994646}
# I1215 15:12:20.333159 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.09599545,
#  'Loss/localization_loss': 0.0014659705,
#  'Loss/regularization_loss': 0.037332993,
#  'Loss/total_loss': 0.13479441,
#  'learning_rate': 0.07994646}
# INFO:tensorflow:Step 7500 per-step time 0.541s
# I1215 15:13:14.430324 139683018876736 model_lib_v2.py:705] Step 7500 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.24967942,
#  'Loss/localization_loss': 0.00586321,
#  'Loss/regularization_loss': 0.037386138,
#  'Loss/total_loss': 0.29292879,
#  'learning_rate': 0.07994425}
# I1215 15:13:14.430579 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.24967942,
#  'Loss/localization_loss': 0.00586321,
#  'Loss/regularization_loss': 0.037386138,
#  'Loss/total_loss': 0.29292879,
#  'learning_rate': 0.07994425}
# INFO:tensorflow:Step 7600 per-step time 0.542s
# I1215 15:14:08.661690 139683018876736 model_lib_v2.py:705] Step 7600 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.24018843,
#  'Loss/localization_loss': 0.0047637923,
#  'Loss/regularization_loss': 0.03741107,
#  'Loss/total_loss': 0.2823633,
#  'learning_rate': 0.079942}
# I1215 15:14:08.661965 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.24018843,
#  'Loss/localization_loss': 0.0047637923,
#  'Loss/regularization_loss': 0.03741107,
#  'Loss/total_loss': 0.2823633,
#  'learning_rate': 0.079942}
# INFO:tensorflow:Step 7700 per-step time 0.537s
# I1215 15:15:02.359959 139683018876736 model_lib_v2.py:705] Step 7700 per-step time 0.537s
# INFO:tensorflow:{'Loss/classification_loss': 0.23013385,
#  'Loss/localization_loss': 0.0045297598,
#  'Loss/regularization_loss': 0.037469357,
#  'Loss/total_loss': 0.27213296,
#  'learning_rate': 0.07993971}
# I1215 15:15:02.360201 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.23013385,
#  'Loss/localization_loss': 0.0045297598,
#  'Loss/regularization_loss': 0.037469357,
#  'Loss/total_loss': 0.27213296,
#  'learning_rate': 0.07993971}
# INFO:tensorflow:Step 7800 per-step time 0.540s
# I1215 15:15:56.378269 139683018876736 model_lib_v2.py:705] Step 7800 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.20168084,
#  'Loss/localization_loss': 0.0038870857,
#  'Loss/regularization_loss': 0.03752327,
#  'Loss/total_loss': 0.2430912,
#  'learning_rate': 0.07993737}
# I1215 15:15:56.378524 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.20168084,
#  'Loss/localization_loss': 0.0038870857,
#  'Loss/regularization_loss': 0.03752327,
#  'Loss/total_loss': 0.2430912,
#  'learning_rate': 0.07993737}
# INFO:tensorflow:Step 7900 per-step time 0.543s
# I1215 15:16:50.707900 139683018876736 model_lib_v2.py:705] Step 7900 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.22614315,
#  'Loss/localization_loss': 0.003287988,
#  'Loss/regularization_loss': 0.037552837,
#  'Loss/total_loss': 0.266984,
#  'learning_rate': 0.079934984}
# I1215 15:16:50.708147 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.22614315,
#  'Loss/localization_loss': 0.003287988,
#  'Loss/regularization_loss': 0.037552837,
#  'Loss/total_loss': 0.266984,
#  'learning_rate': 0.079934984}
# INFO:tensorflow:Step 8000 per-step time 0.543s
# I1215 15:17:44.984278 139683018876736 model_lib_v2.py:705] Step 8000 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.15263532,
#  'Loss/localization_loss': 0.0026532668,
#  'Loss/regularization_loss': 0.037630647,
#  'Loss/total_loss': 0.19291924,
#  'learning_rate': 0.079932556}
# I1215 15:17:44.984533 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.15263532,
#  'Loss/localization_loss': 0.0026532668,
#  'Loss/regularization_loss': 0.037630647,
#  'Loss/total_loss': 0.19291924,
#  'learning_rate': 0.079932556}
# INFO:tensorflow:Step 8100 per-step time 0.547s
# I1215 15:18:39.645939 139683018876736 model_lib_v2.py:705] Step 8100 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.21950401,
#  'Loss/localization_loss': 0.0064962762,
#  'Loss/regularization_loss': 0.037694365,
#  'Loss/total_loss': 0.26369464,
#  'learning_rate': 0.079930075}
# I1215 15:18:39.646221 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.21950401,
#  'Loss/localization_loss': 0.0064962762,
#  'Loss/regularization_loss': 0.037694365,
#  'Loss/total_loss': 0.26369464,
#  'learning_rate': 0.079930075}
# INFO:tensorflow:Step 8200 per-step time 0.538s
# I1215 15:19:33.401946 139683018876736 model_lib_v2.py:705] Step 8200 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.14046028,
#  'Loss/localization_loss': 0.0017676471,
#  'Loss/regularization_loss': 0.037712473,
#  'Loss/total_loss': 0.1799404,
#  'learning_rate': 0.079927556}
# I1215 15:19:33.402298 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.14046028,
#  'Loss/localization_loss': 0.0017676471,
#  'Loss/regularization_loss': 0.037712473,
#  'Loss/total_loss': 0.1799404,
#  'learning_rate': 0.079927556}
# INFO:tensorflow:Step 8300 per-step time 0.542s
# I1215 15:20:27.558284 139683018876736 model_lib_v2.py:705] Step 8300 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.15597208,
#  'Loss/localization_loss': 0.0028593568,
#  'Loss/regularization_loss': 0.037736416,
#  'Loss/total_loss': 0.19656785,
#  'learning_rate': 0.07992499}
# I1215 15:20:27.558529 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.15597208,
#  'Loss/localization_loss': 0.0028593568,
#  'Loss/regularization_loss': 0.037736416,
#  'Loss/total_loss': 0.19656785,
#  'learning_rate': 0.07992499}
# INFO:tensorflow:Step 8400 per-step time 0.544s
# I1215 15:21:21.973322 139683018876736 model_lib_v2.py:705] Step 8400 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.24259588,
#  'Loss/localization_loss': 0.004021395,
#  'Loss/regularization_loss': 0.03779301,
#  'Loss/total_loss': 0.2844103,
#  'learning_rate': 0.079922386}
# I1215 15:21:21.973595 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.24259588,
#  'Loss/localization_loss': 0.004021395,
#  'Loss/regularization_loss': 0.03779301,
#  'Loss/total_loss': 0.2844103,
#  'learning_rate': 0.079922386}
# INFO:tensorflow:Step 8500 per-step time 0.530s
# I1215 15:22:14.948380 139683018876736 model_lib_v2.py:705] Step 8500 per-step time 0.530s
# INFO:tensorflow:{'Loss/classification_loss': 0.28122243,
#  'Loss/localization_loss': 0.0054350975,
#  'Loss/regularization_loss': 0.037860155,
#  'Loss/total_loss': 0.3245177,
#  'learning_rate': 0.07991974}
# I1215 15:22:14.948637 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.28122243,
#  'Loss/localization_loss': 0.0054350975,
#  'Loss/regularization_loss': 0.037860155,
#  'Loss/total_loss': 0.3245177,
#  'learning_rate': 0.07991974}
# INFO:tensorflow:Step 8600 per-step time 0.516s
# I1215 15:23:06.568187 139683018876736 model_lib_v2.py:705] Step 8600 per-step time 0.516s
# INFO:tensorflow:{'Loss/classification_loss': 0.21103968,
#  'Loss/localization_loss': 0.003621534,
#  'Loss/regularization_loss': 0.03790412,
#  'Loss/total_loss': 0.25256532,
#  'learning_rate': 0.079917036}
# I1215 15:23:06.568431 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.21103968,
#  'Loss/localization_loss': 0.003621534,
#  'Loss/regularization_loss': 0.03790412,
#  'Loss/total_loss': 0.25256532,
#  'learning_rate': 0.079917036}
# INFO:tensorflow:Step 8700 per-step time 0.514s
# I1215 15:23:57.939975 139683018876736 model_lib_v2.py:705] Step 8700 per-step time 0.514s
# INFO:tensorflow:{'Loss/classification_loss': 0.14030541,
#  'Loss/localization_loss': 0.002935783,
#  'Loss/regularization_loss': 0.03793113,
#  'Loss/total_loss': 0.18117233,
#  'learning_rate': 0.0799143}
# I1215 15:23:57.940257 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.14030541,
#  'Loss/localization_loss': 0.002935783,
#  'Loss/regularization_loss': 0.03793113,
#  'Loss/total_loss': 0.18117233,
#  'learning_rate': 0.0799143}
# INFO:tensorflow:Step 8800 per-step time 0.512s
# I1215 15:24:49.155576 139683018876736 model_lib_v2.py:705] Step 8800 per-step time 0.512s
# INFO:tensorflow:{'Loss/classification_loss': 0.12131771,
#  'Loss/localization_loss': 0.0013975047,
#  'Loss/regularization_loss': 0.03798282,
#  'Loss/total_loss': 0.16069803,
#  'learning_rate': 0.079911515}
# I1215 15:24:49.155819 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.12131771,
#  'Loss/localization_loss': 0.0013975047,
#  'Loss/regularization_loss': 0.03798282,
#  'Loss/total_loss': 0.16069803,
#  'learning_rate': 0.079911515}
# INFO:tensorflow:Step 8900 per-step time 0.515s
# I1215 15:25:40.619653 139683018876736 model_lib_v2.py:705] Step 8900 per-step time 0.515s
# INFO:tensorflow:{'Loss/classification_loss': 0.15428689,
#  'Loss/localization_loss': 0.0027587288,
#  'Loss/regularization_loss': 0.038016867,
#  'Loss/total_loss': 0.19506249,
#  'learning_rate': 0.079908684}
# I1215 15:25:40.619893 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.15428689,
#  'Loss/localization_loss': 0.0027587288,
#  'Loss/regularization_loss': 0.038016867,
#  'Loss/total_loss': 0.19506249,
#  'learning_rate': 0.079908684}
# INFO:tensorflow:Step 9000 per-step time 0.522s
# I1215 15:26:32.858515 139683018876736 model_lib_v2.py:705] Step 9000 per-step time 0.522s
# INFO:tensorflow:{'Loss/classification_loss': 0.15923637,
#  'Loss/localization_loss': 0.0022388208,
#  'Loss/regularization_loss': 0.03816547,
#  'Loss/total_loss': 0.19964066,
#  'learning_rate': 0.0799058}
# I1215 15:26:32.858753 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.15923637,
#  'Loss/localization_loss': 0.0022388208,
#  'Loss/regularization_loss': 0.03816547,
#  'Loss/total_loss': 0.19964066,
#  'learning_rate': 0.0799058}
# INFO:tensorflow:Step 9100 per-step time 0.543s
# I1215 15:27:27.145764 139683018876736 model_lib_v2.py:705] Step 9100 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.2096525,
#  'Loss/localization_loss': 0.0047710408,
#  'Loss/regularization_loss': 0.038244274,
#  'Loss/total_loss': 0.2526678,
#  'learning_rate': 0.07990289}
# I1215 15:27:27.146055 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.2096525,
#  'Loss/localization_loss': 0.0047710408,
#  'Loss/regularization_loss': 0.038244274,
#  'Loss/total_loss': 0.2526678,
#  'learning_rate': 0.07990289}
# INFO:tensorflow:Step 9200 per-step time 0.541s
# I1215 15:28:21.218515 139683018876736 model_lib_v2.py:705] Step 9200 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.16323753,
#  'Loss/localization_loss': 0.0033877676,
#  'Loss/regularization_loss': 0.03829672,
#  'Loss/total_loss': 0.204922,
#  'learning_rate': 0.07989992}
# I1215 15:28:21.218752 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.16323753,
#  'Loss/localization_loss': 0.0033877676,
#  'Loss/regularization_loss': 0.03829672,
#  'Loss/total_loss': 0.204922,
#  'learning_rate': 0.07989992}
# INFO:tensorflow:Step 9300 per-step time 0.546s
# I1215 15:29:15.808237 139683018876736 model_lib_v2.py:705] Step 9300 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.11290711,
#  'Loss/localization_loss': 0.0019288212,
#  'Loss/regularization_loss': 0.03840963,
#  'Loss/total_loss': 0.15324557,
#  'learning_rate': 0.07989691}
# I1215 15:29:15.808481 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.11290711,
#  'Loss/localization_loss': 0.0019288212,
#  'Loss/regularization_loss': 0.03840963,
#  'Loss/total_loss': 0.15324557,
#  'learning_rate': 0.07989691}
# INFO:tensorflow:Step 9400 per-step time 0.545s
# I1215 15:30:10.277814 139683018876736 model_lib_v2.py:705] Step 9400 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.18516098,
#  'Loss/localization_loss': 0.0029160285,
#  'Loss/regularization_loss': 0.038438525,
#  'Loss/total_loss': 0.22651553,
#  'learning_rate': 0.079893865}
# I1215 15:30:10.278062 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.18516098,
#  'Loss/localization_loss': 0.0029160285,
#  'Loss/regularization_loss': 0.038438525,
#  'Loss/total_loss': 0.22651553,
#  'learning_rate': 0.079893865}
# INFO:tensorflow:Step 9500 per-step time 0.543s
# I1215 15:31:04.602512 139683018876736 model_lib_v2.py:705] Step 9500 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.18930952,
#  'Loss/localization_loss': 0.0042030853,
#  'Loss/regularization_loss': 0.03846709,
#  'Loss/total_loss': 0.2319797,
#  'learning_rate': 0.079890765}
# I1215 15:31:04.602774 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.18930952,
#  'Loss/localization_loss': 0.0042030853,
#  'Loss/regularization_loss': 0.03846709,
#  'Loss/total_loss': 0.2319797,
#  'learning_rate': 0.079890765}
# INFO:tensorflow:Step 9600 per-step time 0.544s
# I1215 15:31:59.019992 139683018876736 model_lib_v2.py:705] Step 9600 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.1633895,
#  'Loss/localization_loss': 0.0029460876,
#  'Loss/regularization_loss': 0.038519435,
#  'Loss/total_loss': 0.20485502,
#  'learning_rate': 0.07988763}
# I1215 15:31:59.020234 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.1633895,
#  'Loss/localization_loss': 0.0029460876,
#  'Loss/regularization_loss': 0.038519435,
#  'Loss/total_loss': 0.20485502,
#  'learning_rate': 0.07988763}
# INFO:tensorflow:Step 9700 per-step time 0.543s
# I1215 15:32:53.307993 139683018876736 model_lib_v2.py:705] Step 9700 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.17350936,
#  'Loss/localization_loss': 0.0021376037,
#  'Loss/regularization_loss': 0.038560696,
#  'Loss/total_loss': 0.21420765,
#  'learning_rate': 0.07988444}
# I1215 15:32:53.308234 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.17350936,
#  'Loss/localization_loss': 0.0021376037,
#  'Loss/regularization_loss': 0.038560696,
#  'Loss/total_loss': 0.21420765,
#  'learning_rate': 0.07988444}
# INFO:tensorflow:Step 9800 per-step time 0.542s
# I1215 15:33:47.512151 139683018876736 model_lib_v2.py:705] Step 9800 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.1108722,
#  'Loss/localization_loss': 0.0022585874,
#  'Loss/regularization_loss': 0.038590156,
#  'Loss/total_loss': 0.15172094,
#  'learning_rate': 0.079881206}
# I1215 15:33:47.512456 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.1108722,
#  'Loss/localization_loss': 0.0022585874,
#  'Loss/regularization_loss': 0.038590156,
#  'Loss/total_loss': 0.15172094,
#  'learning_rate': 0.079881206}
# INFO:tensorflow:Step 9900 per-step time 0.543s
# I1215 15:34:41.821254 139683018876736 model_lib_v2.py:705] Step 9900 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.17117442,
#  'Loss/localization_loss': 0.002523535,
#  'Loss/regularization_loss': 0.038618527,
#  'Loss/total_loss': 0.21231648,
#  'learning_rate': 0.07987793}
# I1215 15:34:41.821506 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.17117442,
#  'Loss/localization_loss': 0.002523535,
#  'Loss/regularization_loss': 0.038618527,
#  'Loss/total_loss': 0.21231648,
#  'learning_rate': 0.07987793}
# INFO:tensorflow:Step 10000 per-step time 0.542s
# I1215 15:35:36.008226 139683018876736 model_lib_v2.py:705] Step 10000 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.15839234,
#  'Loss/localization_loss': 0.003264932,
#  'Loss/regularization_loss': 0.03868808,
#  'Loss/total_loss': 0.20034535,
#  'learning_rate': 0.07987461}
# I1215 15:35:36.008501 139683018876736 model_lib_v2.py:708] {'Loss/classification_loss': 0.15839234,
#  'Loss/localization_loss': 0.003264932,
#  'Loss/regularization_loss': 0.03868808,
#  'Loss/total_loss': 0.20034535,
#  'learning_rate': 0.07987461}

# %% [markdown]
# ## evaluation results in tensorboard

# %% [markdown]
# ![eval_charts.png](eval_charts.png "eval charts")

# %% [markdown]
# ![eval_images.png](eval_images.png "eval images")

# %% [markdown]
# ### from the above chart, we can see that the mAP@0.5IOU is about 0.85

# %% [markdown]
# # Testing with unseen dataset

# %%
# load model
import time
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL = "run3/saved_model"

print('Loading model...', end='')
start_time = time.time()

# Load saved model and build the detection function
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))
# Out:
# Loading model...Done! Took 42.449697732925415 seconds

# %%
# load label map for plotting
category_index = label_map_util.create_category_index_from_labelmap('label_map.pbtxt', use_display_name=True)

# %%
# %matplotlib inline

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

IMAGE_PATHS = ['door1.jpg', 'door2.jpg', 'stairs1.jpg', 'stairs2.jpg', 'door+stairs1.jpg', 'door+stairs2.jpg']

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.

    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.

    Args:
      path: the file path to the image

    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))


for image_path in IMAGE_PATHS:

    print('Running inference for {}... '.format(image_path), end='')

    image_np = load_image_into_numpy_array(image_path)

    # Things to try:
    # Flip horizontally
    # image_np = np.fliplr(image_np).copy()

    # Convert image to grayscale
    # image_np = np.tile(
    #     np.mean(image_np, 2, keepdims=True), (1, 1, 3)).astype(np.uint8)

    # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
    input_tensor = tf.convert_to_tensor(image_np)
    # The model expects a batch of images, so add an axis with `tf.newaxis`.
    input_tensor = input_tensor[tf.newaxis, ...]

    # input_tensor = np.expand_dims(image_np, 0)
    detections = detect_fn(input_tensor)

    # All outputs are batches tensors.
    # Convert to numpy arrays, and take index [0] to remove the batch dimension.
    # We're only interested in the first num_detections.
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                   for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
          image_np_with_detections,
          detections['detection_boxes'],
          detections['detection_classes'],
          detections['detection_scores'],
          category_index,
          use_normalized_coordinates=True,
          max_boxes_to_draw=200,
          min_score_thresh=.30,
          line_thickness=8,
          agnostic_mode=False)

    plt.figure()
    plt.imshow(image_np_with_detections)
    print('Done')
plt.show()
# Out:
# Running inference for door1.jpg... Done
# Running inference for door2.jpg... Done
# Running inference for stairs1.jpg... Done
# Running inference for stairs2.jpg... Done
# Running inference for door+stairs1.jpg... Done
# Running inference for door+stairs2.jpg... Done
